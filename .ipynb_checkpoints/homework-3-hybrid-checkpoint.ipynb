# %% [markdown]
# # Домашняя работа 3. Гибридные рекомендательные системы

# %% [markdown]
# Датасет ml-latest
#  - Вспомнить подходы, которые мы разбирали
#  - Выбрать понравившийся подход к гибридным системам
#  - Написать свою
#
# Решением будет ссылка на гитхаб с готовым ноутбуком

# %% [markdown]
# ## Импорт библиотек

# %%
import pandas as pd
import numpy as np

# Пакет Surprise
import numpy as np

# %matplotlib inline

# %% [markdown]
# ## Загрузка данных

# %%
movies = pd.read_csv('../data/ml-latest-small/movies.csv', )
links = pd.read_csv('../data/ml-latest-small/links.csv')
tags = pd.read_csv('../data/ml-latest-small/tags.csv')
ratings = pd.read_csv('../data/ml-latest-small/ratings.csv',)

# %% [markdown]
# ## Построение гибридной рекомендательной системы
#
#  - Холодный старт (до 5 оценок) - рекомендуем наиболее популярные фильмы
#  - Теплый старт (от 5 до 10 оценок) - рекомендуем фильмы на основе сожержания со стекингом
#  - Горячий старт (от 10 до бесконечности оценок) - коллаборативная фильтрация с блендингом (Item, User based)

# %% [markdown]
# ##### Холодный старт - наиболее популярные фильмы

# %%
# Рекомендательная система для холодного старта
movies_ratings = ratings.groupby('movieId').agg({'userId': np.count_nonzero, 
                                'rating': [np.median, np.var, np.average]})
movies_ratings.columns=['userid_count', 'rating_median', 'rating_var', 'rating_average']

# %%
# Нормируем количество оценок пользователей и рейтинг фильмов
movies_ratings['norm_raiting'] = movies_ratings.apply(lambda row: (row['rating_average'])
                             /(movies_ratings['rating_average'].max() - movies_ratings['rating_average'].min())
                 , axis=1)
movies_ratings['norm_userid'] = movies_ratings.apply(lambda row: (row['userid_count'])
                             /(movies_ratings['userid_count'].max() - movies_ratings['userid_count'].min())
                 , axis=1)
# Популярность фильма = нормированный райтинг * нормированное количество оценок
movies_ratings['popularity'] = movies_ratings['norm_userid'] * movies_ratings['norm_raiting']
movies_popularity = movies_ratings.merge(movies, on='movieId', how='left', sorted=False)[['title', 'genres', 'popularity']]

# %%
def cold_start(userId):
    movies = movies_popularity.sort_values('popularity', ascending=False)[['movieId', 'title', 'popularity']].head(10)
    return movies

# %% [markdown]
# #### Теплый старт - рекомендация на основе содержания

# %%
# Сгруппируем тэги для фильмов
grouped_tags = tags.groupby('movieId').agg({'tag': [(lambda x: "|".join(np.unique(x))), np.count_nonzero]})
grouped_tags.columns=['all_tags', 'all_tags_count']

# Сгруппируем тэги для фильмов по пользователями
grouped_user_tags = tags.groupby(['movieId', 'userId'])\
                        .agg({'tag': [(lambda x: "|".join(np.unique(x))), np.count_nonzero]})
grouped_user_tags.columns=['user_tags', 'user_tags_count']

# %%
# Датасет фильмов и оценок пользователей к ним
movies_ratings_tags = movies.merge(ratings, on='movieId', how='left', sort=False)\
                       .merge(grouped_tags, on=['movieId'], how='left', sort=False)\
                       .merge(grouped_user_tags, on=['movieId', 'userId'], how='left', sort=False)

# Посмотрим на получившийся датасет 
movies_ratings_tags[(movies_ratings_tags.user_tags.isna()==False)].head(5)
# Out:
#      movieId             title                                       genres  \
# 121        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 164        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 193        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 223        2    Jumanji (1995)                   Adventure|Children|Fantasy
# 292        2    Jumanji (1995)                   Adventure|Children|Fantasy
#
#      userId  rating     timestamp  \
# 121   336.0     4.0  1.122227e+09
# 164   474.0     4.0  9.785758e+08
# 193   567.0     3.5  1.525286e+09
# 223    62.0     4.0  1.528844e+09
# 292   474.0     3.0  1.046887e+09
#
#                                          all_tags  all_tags_count  \
# 121                                     fun|pixar             3.0
# 164                                     fun|pixar             3.0
# 193                                     fun|pixar             3.0
# 223  Robin Williams|fantasy|game|magic board game             4.0
# 292  Robin Williams|fantasy|game|magic board game             4.0
#
#                                    user_tags  user_tags_count
# 121                                    pixar              1.0
# 164                                    pixar              1.0
# 193                                      fun              1.0
# 223  Robin Williams|fantasy|magic board game              3.0
# 292                                     game              1.0

# %% [markdown]
# ###### Сформируем следующие признаки, для того чтобы сделать Content-bases рекомендации:
#     1) TF-IDF метрика на жанрах и тегах
#     2) Средняя оценка пользователя и фильма
#     3) Медианная оценка пользователя и фильма
#     4) Дисперсия оценки пользователя и фильма
#     5) Количество оценок пользователя и фильма
#
# Так же обогатим модель результатами **логистической регрессии** для оценки пользователя,
# после обучим алгоритм **KNN** на полученных данных

# %%
# Функция для TF-IDF метрики
def tf_idf(row, val):
    return (1/len(row[val].split('|')))*dict_genres_idf[i] if i in row[val] else 0

# Сформируем словарь жанров:
genres = []
for i in movies.genres.str.split('|'):
    for j in i:
        genres.append(j)
        
### Итоговый словарь жанров:
dict_genres_idf = {i:np.log(len(movies)/genres.count(i)) for i in genres}

# %%
# Добавим новые фичи в датасет (TF-IDF на жанрах):
for i in dict_genres_idf:
    movies_ratings_tags['tf_idf_'+i] = movies_ratings_tags.apply(lambda row: tf_idf(row, 'genres'), axis=1)

# %%
grouped_tags
# Out:
#                                                   all_tags  all_tags_count
# movieId
# 1                                                fun|pixar               3
# 2             Robin Williams|fantasy|game|magic board game               4
# 3                                                moldy|old               2
# 5                                         pregnancy|remake               2
# 7                                                   remake               1
# 11                                      politics|president               2
# 14                                      politics|president               2
# 16                                                   Mafia               1
# 17                                             Jane Austen               1
# 21                                               Hollywood               1
# 22                                           serial killer               1
# 25                                              alcoholism               1
# 26                                             Shakespeare               1
# 28                            In Netflix queue|Jane Austen               2
# 29                                              kidnapping               1
# 31                                     high school|teacher               2
# 32       Brad Pitt|Bruce Willis|Post apocalyptic|mindfu...              10
# 34       Animal movie|pigs|villain nonexistent or not n...               3
# 36                                       Nun|death penalty               2
# 38                                                   twins               1
# 39       Emma|Jane Austen|Paul Rudd|chick flick|funny|q...               7
# 40                           In Netflix queue|South Africa               2
# 41                                             Shakespeare               1
# 43                                                 England               1
# 45                                              Journalism               1
# 46                                                 wedding               1
# 47                      mystery|serial killer|twist ending               3
# 50       heist|mindfuck|suspense|thriller|tricky|twist ...               6
# 52                                   adoption|prostitution               2
# 58                                                 writing               1
# ...                                                    ...             ...
# 144210                      Sustainability|dumpster diving               2
# 148626                             Witty|funny|interesting               3
# 148881                                 Existential|surreal               2
# 152077                                     creepy|suspense               2
# 152711       Cambodia|crime|human rights|murder|procedural               5
# 153070                                           nightmare               1
# 155288                          suspense|thought-provoking               2
# 156371                                                80's               1
# 156605                            quirky|sweet|understated               3
# 158872          Crude humor|Vulgar|mindfuck|sarcasm|satire               5
# 158966   Viggo Mortensen|building a family|creative|fre...               6
# 161634                                             intense               1
# 164179   Cerebral|beautiful visuals|cinematography|good...               7
# 164909                      Bittersweet|visually appealing               2
# 167746                                  funny|heartwarming               2
# 168248   Heroic Bloodshed|Keanu Reeves|action|dark hero...               8
# 168252   dark|emotional|gritty|heartbreaking|predictibl...               5
# 170945                                Suspenseful|paranoia               2
# 174053   Dystopia|future|interesting|jon hamm|thought p...               5
# 174055                           brilliant|inspiring|tense               3
# 176371   atmospheric|beautiful|cinematography|dark|drea...               8
# 176419                allegorical|uncomfortable|unsettling               3
# 179401                  Action|Comedy|Dwayne Johnson|funny               4
# 180031                               atmospheric|dreamlike               2
# 180985                                           bad music               1
# 183611                         Comedy|Rachel McAdams|funny               3
# 184471     Alicia Vikander|adventure|video game adaptation               3
# 187593                   Josh Brolin|Ryan Reynolds|sarcasm               3
# 187595                             Emilia Clarke|star wars               2
# 193565                       anime|comedy|gintama|remaster               4
#
# [1572 rows x 2 columns]

# %%
# Сформируем словарь тэгов:
tags = []
for i in movies_ratings_tags[(grouped_tags.tags.str.split('|'):
    for j in i :
        tags.append(j)
        
# Итоговый словарь тэгов
dict_tags_idf = {i:tags.count(i) for i in tags if tags.count(i)>5 and i!=''}
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-99-9ddaaa504e6f> in <module>()
#       5         tags.append(j)
#       6 # Итоговый словарь тэгов
# ----> 7 dict_tags_idf = {i:tags.count(i) for i in tags if tags.count(i)>5 and i!=''}
#
# <ipython-input-99-9ddaaa504e6f> in <dictcomp>(.0)
#       5         tags.append(j)
#       6 # Итоговый словарь тэгов
# ----> 7 dict_tags_idf = {i:tags.count(i) for i in tags if tags.count(i)>5 and i!=''}
#
# KeyboardInterrupt:

# %%
# Добавим новые фичи в датасет (TF-IDF на тэгах для пользователя и фильма):
for i in dict_tags_idf:
    movies_ratings_tags['tf_idf_'+i] = movies_ratings_tags.apply(lambda row: tf_idf(row, 'all_tags'), axis=1)
    movies_ratings_tags['user_tf_idf_'+i] = movies_ratings_tags.apply(lambda row: tf_idf(row, 'user_tags'), axis=1)

# %% [markdown]
# #### Горячий старт - коллаборативная фильтрация
